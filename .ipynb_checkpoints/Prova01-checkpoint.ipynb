# %%
a = int(input("digite um valor"))
b = int(input("digite um valor"))
c = int(input("digite um valor"))
if a <= b and a<=c :
    maior1= b 
    maior2= c
elif b<= a and b <= c :
    maior1 = a 
    maior2 = c 
else:
    maior1=a
    maior2=b 
media = (maior1+maior2) / 2
print("maiores são  media")
print(maior1 ,  maior2 , media)
